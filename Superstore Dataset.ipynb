# %%
#Superstore Dataset
#https://www.kaggle.com/datasets/vivek468/superstore-dataset-final
#About Dataset
"""
Context With growing demands and cut-throat competitions in the market, a Superstore Giant is seeking your knowledge in understanding what works best for them. They would like to understand which products, regions, categories and customer segments they should target or avoid.

You can even take this a step further and try and build a Regression model to predict Sales or Profit.

Go crazy with the dataset, but also make sure to provide some business insights to improve.

Metadata
Row ID => Unique ID for each row.
Order ID => Unique Order ID for each Customer.
Order Date => Order Date of the product.
Ship Date => Shipping Date of the Product.
Ship Mode=> Shipping Mode specified by the Customer.
Customer ID => Unique ID to identify each Customer.
Customer Name => Name of the Customer.
Segment => The segment where the Customer belongs.
Country => Country of residence of the Customer.
City => City of residence of of the Customer.
State => State of residence of the Customer.
Postal Code => Postal Code of every Customer.
Region => Region where the Customer belong.
Product ID => Unique ID of the Product.
Category => Category of the product ordered.
Sub-Category => Sub-Category of the product ordered.
Product Name => Name of the Product
Sales => Sales of the Product.
Quantity => Quantity of the Product.
Discount => Discount provided.
Profit => Profit/Loss incurred.

"""
# Out:
# '\nContext With growing demands and cut-throat competitions in the market, a Superstore Giant is seeking your knowledge in understanding what works best for them. They would like to understand which products, regions, categories and customer segments they should target or avoid.\n\nYou can even take this a step further and try and build a Regression model to predict Sales or Profit.\n\nGo crazy with the dataset, but also make sure to provide some business insights to improve.\n\nMetadata\nRow ID => Unique ID for each row.\nOrder ID => Unique Order ID for each Customer.\nOrder Date => Order Date of the product.\nShip Date => Shipping Date of the Product.\nShip Mode=> Shipping Mode specified by the Customer.\nCustomer ID => Unique ID to identify each Customer.\nCustomer Name => Name of the Customer.\nSegment => The segment where the Customer belongs.\nCountry => Country of residence of the Customer.\nCity => City of residence of of the Customer.\nState => State of residence of the Cust
# ...

# %%
import os

# Get the current working directory
current_directory = os.getcwd()

# Print the current working directory
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: h:\data analyticts\portfolio\New folder

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Sample - Superstore.csv",encoding='latin1')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# No Null item
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
import datetime as dt
df['Order Date']=pd.to_datetime(df['Order Date'])
df['Ship Date']=pd.to_datetime(df['Ship Date'])

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
#No duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#new feature Profit Margin
df['Profit Margin'] = df['Profit'] / df['Sales']

# %%
#new feature
df.insert(loc=3,column='Order Year',value=df['Order Date'].dt.year)

# %%
#new feature
df.insert(loc=4,column='Order Month',value=df['Order Date'].dt.month)

# %%
#new feature
df.insert(5,'Order Processing Time',(df['Ship Date'] - df['Order Date']).dt.days)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Year', 'Order Month',
#        'Order Processing Time', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Profit Margin'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sns.histplot(data=df, x='Sales', bins=150, kde=False, color='blue')
plt.title('Histogram of Sales')
plt.xlabel('Sales Value')
plt.xlim(0,)
plt.ylabel('Amount')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df, x='Profit', bins=150, kde=False, color='blue')
plt.title('Histogram of Profit')
plt.xlabel('Profit Value')
plt.xlim(0,)
plt.ylabel('Amount')
plt.show()

# %%
sns.boxplot(data=df,x='Profit')
plt.show()

# %%
sns.boxplot(data=df,x='Sales')
plt.show()

# %%
# Apply abs function to convert negative values to positive
df['Abs Profit'] = df['Profit'].abs()

# Apply log1p transformation
df['Log Profit'] = np.log1p(df['Abs Profit'])

# %%
sns.boxplot(data=df,x='Log Profit')
plt.show()

# %%
sns.violinplot(data=df, x='Sales', y='Category', hue='Category', palette='pastel')
plt.title('Violin Plot of Sales')
plt.xlabel('Sales Value')
plt.ylabel('Value')
plt.show()

# %%
sns.violinplot(data=df, x='Sales', y='Sub-Category', hue='Sub-Category', palette='pastel')
plt.title('Violin Plot of Sales')
plt.xlabel('Sales Value')
plt.ylabel('Value')
plt.show()

# %%
sns.violinplot(data=df, x='Sales', y='Region', hue='Region', palette='pastel')
plt.title('Violin Plot of Sales')
plt.xlabel('Sales Value')
plt.ylabel('Value')
plt.show()

# %%
sns.countplot(data=df, x='Category')
plt.title('Distribution of Categories')
plt.show()

# %%
df['Region'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Regions')
plt.ylabel('')
plt.show()

# %%
sns.pairplot(df[['Sales', 'Profit', 'Quantity', 'Discount']])
plt.show()

# %%
corr = df[['Sales', 'Profit', 'Quantity', 'Discount']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.scatterplot(data=df, x='Sales', y='Profit', hue='Category')
plt.title('Sales vs Profit by Category')
plt.show()

# %%
df.set_index('Order Date', inplace=True)
# Monthly sales
monthly_sales = df['Sales'].resample('ME').sum()

# Yearly sales
yearly_sales = df['Sales'].resample('YE').sum()

# Plot monthly sales
plt.figure(figsize=(14, 7))
sns.lineplot(data=monthly_sales)
plt.title('Monthly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# Plot yearly sales
plt.figure(figsize=(14, 7))
sns.lineplot(data=yearly_sales)
plt.title('Yearly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# Extract month and year for seasonal analysis
df['Month'] = df.index.month
df['Year'] = df.index.year

# Monthly seasonal pattern
plt.figure(figsize=(14, 7))
sns.boxplot(x='Month', y='Sales', data=df)
plt.title('Monthly Seasonal Sales Pattern')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# Yearly seasonal pattern
plt.figure(figsize=(14, 7))
sns.boxplot(x='Year', y='Sales', data=df)
plt.title('Yearly Seasonal Sales Pattern')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.show()

# %%
df.reset_index(inplace=True)

# %%
df.groupby('Customer ID')['Order Date'].max()
# Out:
# Customer ID
# AA-10315   2017-06-29
# AA-10375   2017-12-11
# AA-10480   2017-04-15
# AA-10645   2017-11-05
# AB-10015   2016-11-10
#               ...
# XP-21865   2017-11-17
# YC-21895   2017-12-26
# YS-21880   2017-12-21
# ZC-21910   2017-11-06
# ZD-21925   2017-06-11
# Name: Order Date, Length: 793, dtype: datetime64[ns]

# %%
df.columns
# Out:
# Index(['Order Date', 'Row ID', 'Order ID', 'Order Year', 'Order Month',
#        'Order Processing Time', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Profit Margin',
#        'Log Profit', 'Abs Profit', 'Month', 'Year', 'Recency', 'Frequency',
#        'Monetary'],
#       dtype='object')

# %%
# Convert 'Order Date' to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Calculate Recency
current_date = df['Order Date'].max() + pd.DateOffset(1)
df['Recency'] = (current_date - df.groupby('Customer ID')['Order Date'].transform('max')).dt.days

# Calculate Frequency
df['Frequency'] = df.groupby('Customer ID')['Order ID'].transform('nunique')

# Calculate Monetary
df['Monetary'] = df.groupby('Customer ID')['Sales'].transform('sum')

# Select the RFM columns
rfm_df = df[['Customer ID', 'Recency', 'Frequency', 'Monetary']].drop_duplicates()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm_df[['Recency', 'Frequency', 'Monetary']])

# %%
from sklearn.cluster import KMeans

# Determine the optimal number of clusters using the Elbow Method
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(rfm_scaled)
    sse.append(kmeans.inertia_)

# Plot the SSE to find the elbow point
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), sse, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.title('Elbow Method')
plt.show()

# From the plot, choose the optimal number of clusters 
optimal_clusters = 4
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
rfm_df['Cluster'] = kmeans.fit_predict(rfm_scaled)

# %%
# Calculate the mean RFM values for each cluster, excluding 'Customer ID'
cluster_analysis = rfm_df.groupby('Cluster').mean(numeric_only=True).reset_index()

print(cluster_analysis)
# Out:
#    Cluster     Recency  Frequency     Monetary
# 0        0   66.539043   5.659950  1918.212175
# 1        1  735.390244   2.926829  1490.556293
# 2        2   77.489083   9.030568  5505.067508
# 3        3  340.436508   4.555556  1697.598090

# %%
# Calculate the mean RFM values for each cluster
cluster_analysis1 = rfm_df.groupby('Cluster').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'Monetary': 'mean',
    'Customer ID': 'count'
}).rename(columns={'Customer ID': 'Customer Count'}).reset_index()

print(cluster_analysis1)
# Out:
#    Cluster     Recency  Frequency     Monetary  Customer Count
# 0        0   66.539043   5.659950  1918.212175             397
# 1        1  735.390244   2.926829  1490.556293              41
# 2        2   77.489083   9.030568  5505.067508             229
# 3        3  340.436508   4.555556  1697.598090             126

# %%
# Plot the clusters
plt.figure(figsize=(12, 8))
sns.scatterplot(data=rfm_df, x='Recency', y='Frequency', hue='Cluster', palette='viridis', s=100)
plt.title('Customer Segments based on RFM')
plt.xlabel('Recency')
plt.ylabel('Frequency')
plt.show()

# %%
# Group by 'Product Name' and sum the 'Sales'
top_selling_products = df.groupby('Product Name')['Sales'].sum().reset_index()

# Sort the products by 'Sales' in descending order
top_selling_products = top_selling_products.sort_values(by='Sales', ascending=False)

print(top_selling_products.head(10))  # Display the top 10 selling products
# Out:
#                                           Product Name      Sales
# 404              Canon imageCLASS 2200 Advanced Copier  61599.824
# 650  Fellowes PB500 Electric Punch Plastic Comb Bin...  27453.384
# 444  Cisco TelePresence System EX90 Videoconferenci...  22638.480
# 786       HON 5400 Series Task Chairs for Big and Tall  21870.576
# 686         GBC DocuBind TL300 Electric Binding System  19823.479
# 688   GBC Ibimaster 500 Manual ProClick Binding System  19024.500
# 805               Hewlett Packard LaserJet 3310 Copier  18839.686
# 787  HP Designjet T520 Inkjet Large Format Printer ...  18374.895
# 683          GBC DocuBind P400 Electric Binding System  17965.068
# 813        High Speed Automatic Electric Letter Opener  17030.312

# %%
# Group by 'Category' and sum the 'Profit'
most_profitable_categories = df.groupby('Category')['Profit'].sum().reset_index()

# Sort the categories by 'Profit' in descending order
most_profitable_categories = most_profitable_categories.sort_values(by='Profit', ascending=False)

print(most_profitable_categories)
# Out:
#           Category       Profit
# 2       Technology  145454.9481
# 1  Office Supplies  122490.8008
# 0        Furniture   18451.2728

# %%
# Top-selling products
plt.figure(figsize=(12, 6))
sns.barplot(x='Sales', y='Product Name', data=top_selling_products.head(10),hue='Product Name',legend=False, palette='viridis')
plt.title('Top 10 Selling Products')
plt.xlabel('Total Sales')
plt.ylabel('Product Name')
plt.show()

# Most profitable categories
plt.figure(figsize=(12, 6))
sns.barplot(x='Profit', y='Category', data=most_profitable_categories,hue='Category',legend=False, palette='viridis')
plt.title('Most Profitable Categories')
plt.xlabel('Total Profit')
plt.ylabel('Category')
plt.show()

# %%
sales_by_region = df.groupby('Region')['Sales'].sum().reset_index()
print(sales_by_region)
# Out:
#     Region        Sales
# 0  Central  501239.8908
# 1     East  678781.2400
# 2    South  391721.9050
# 3     West  725457.8245

# %%
sales_by_state = df.groupby('State')['Sales'].sum().reset_index()
print(sales_by_state)
# Out:
#                    State        Sales
# 0                Alabama   19510.6400
# 1                Arizona   35282.0010
# 2               Arkansas   11678.1300
# 3             California  457687.6315
# 4               Colorado   32108.1180
# 5            Connecticut   13384.3570
# 6               Delaware   27451.0690
# 7   District of Columbia    2865.0200
# 8                Florida   89473.7080
# 9                Georgia   49095.8400
# 10                 Idaho    4382.4860
# 11              Illinois   80166.1010
# 12               Indiana   53555.3600
# 13                  Iowa    4579.7600
# 14                Kansas    2914.3100
# 15              Kentucky   36591.7500
# 16             Louisiana    9217.0300
# 17                 Maine    1270.5300
# 18              Maryland   23705.5230
# 19         Massachusetts   28634.4340
# 20              Michigan   76269.6140
# 21             Minnesota   29863.1500
# 22           Mississippi   10771.3400
# 23              Missouri   22205.1500
# ...

# %%
sales_by_city = df.groupby('City')['Sales'].sum().reset_index()
print(sales_by_city)
# Out:
#             City     Sales
# 0       Aberdeen    25.500
# 1        Abilene     1.392
# 2          Akron  2729.986
# 3    Albuquerque  2220.160
# 4     Alexandria  5519.570
# ..           ...       ...
# 526   Woonsocket   195.550
# 527      Yonkers  7657.666
# 528         York   817.978
# 529      Yucaipa    50.800
# 530         Yuma   840.865
#
# [531 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(sales_by_region.pivot_table(values='Sales', index='Region', aggfunc='sum'), annot=True, cmap='YlGnBu')
plt.title('Sales by Region')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(sales_by_state.pivot_table(values='Sales', index='State', aggfunc='sum'), annot=True, cmap='YlGnBu')
plt.title('Sales by State')
plt.show()

# %%
top_cities = df.groupby('City')['Sales'].sum().nlargest(10).reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Sales', y='City', data=top_cities,hue='City',legend=False, palette='viridis')
plt.title('Top 10 Cities by Sales')
plt.show()

# %%
top_states = df.groupby('State')['Sales'].sum().nlargest(10).reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Sales', y='State', data=top_states,hue='State',legend=False, palette='viridis')
plt.title('Top 10 States by Sales')
plt.show()

# %%
sales_by_region = df.groupby('Region')['Sales'].sum().reset_index()

plt.figure(figsize=(10, 6))
sns.heatmap(sales_by_region.pivot_table(values='Sales', index='Region', aggfunc='sum'), annot=True, cmap='YlGnBu')
plt.title('Sales by Region')
plt.show()

# %%
import plotly.express as px

fig = px.treemap(df, path=['Region', 'State'], values='Sales', title='Sales by State and Region')
fig.show()

# %%
state_abbreviations = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS',
    'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA',
    'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO', 'Montana': 'MT',
    'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ', 'New Mexico': 'NM',
    'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK',
    'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD',
    'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA',
    'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}

# Map the state names to abbreviations
df['State'] = df['State'].map(state_abbreviations)
import plotly.express as px

# Ensure 'Sales' is numeric
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')
df1=df.groupby('State')['Sales'].sum().reset_index()

fig = px.choropleth(df1, 
                    locations='State', 
                    locationmode='USA-states', 
                    color='Sales', 
                    scope='usa', 
                    title='Sales by State',
                    color_continuous_scale='Viridis')

# Set the color scale range
fig.update_coloraxes(cmin=df['Sales'].min(), cmax=df['Sales'].max())

fig.show()

# %%
correlation_discount_sales = df['Discount'].corr(df['Sales'])
print(f"Correlation between Discount and Sales: {correlation_discount_sales}")
# Out:
# Correlation between Discount and Sales: -0.028190124157535575

# %%
# Group by Ship Mode and calculate the mean profit
profit_by_ship_mode = df.groupby('Ship Mode')['Profit'].mean()
print(profit_by_ship_mode)
# Out:
# Ship Mode
# First Class       31.839948
# Same Day          29.266591
# Second Class      29.535545
# Standard Class    27.494770
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Discount'], df['Sales'], alpha=0.5, edgecolors='w', linewidth=0.5)
plt.title('Correlation between Discount and Sales')
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
profit_by_ship_mode = df.groupby('Ship Mode')['Profit'].mean().reset_index()

plt.figure(figsize=(10, 6))
plt.bar(profit_by_ship_mode['Ship Mode'], profit_by_ship_mode['Profit'], color='skyblue')
plt.title('Impact of Ship Mode on Profit')
plt.xlabel('Ship Mode')
plt.ylabel('Average Profit')
plt.grid(True)
plt.show()
